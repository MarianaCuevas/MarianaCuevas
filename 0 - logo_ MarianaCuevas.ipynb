# %% [markdown]
#    ![](http://tectijuana.edu.mx/wp-content/uploads/2014/11/Heading-Ing-sistemas-2048x672.png),
#    # Iniciarás con Markdown (MD) las generales del Notebook
#    ## 0 - logo_MarianaCuevas
#    ## Generar una imagen con patrones
#    ##  Mariana Cuevas Verdi
#    ## 01/Sep/2017

# %%
import numpy as np
from bokeh.plotting import figure, show, output_notebook

# %% [markdown]
# # algorithm

# %%
xs, ys, cs = [], [], []

for x in range(0, 30):
    for y in range(0, 30):
        up = np.random.randint(0, 2)
        xs.append([x, x + .8])
        ys.append([y + .8 * (up >= .5), y + .8 * (up < .5)])

        col = np.random.randint(0, 4)
        cs.append({0: 'blue', 1: 'red', 2: 'white', 3: 'white'}[col])

# %% [markdown]
# # plot

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e4c8b01f-3f80-4e7d-a302-f1bd29923995">Loading BokehJS ...</span>
#     </div>

# %%
plot = figure(plot_width=800, plot_height=800)

plot.grid.visible = False
plot.xaxis.visible = False
plot.yaxis.visible = False

plot.multi_line(xs, ys, color=cs, line_width=6, line_alpha=.1, line_cap='round')
plot.multi_line(xs, ys, color='black')

show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a84bb44b-3902-4ede-be17-4c840853ed70"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a84bb44b-3902-4ede-be17-4c840853ed70");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a84bb44b-3902-4ede-be17-4c840853ed70");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a84bb44b-3902-4ede-be17-4c840853ed70' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7d5a4819-5b2d-44fd-875f-39c3aee4f63f":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a157fd5c-4705-4b76-a71d-0a62a59263f3","type":"BoxAnnotation"},{"attributes":{},"id":"2a3c6c9a-5cd7-4dc0-ac84-352362b2ddf4","type":"BasicTickFormatter"},{"attributes":{},"id":"75199da5-bb5a-418e-8b93-7cdeb1d318d1","type":"BasicTickFormatter"},{"attributes":{"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"998aef9a-14b7-444f-bd6f-2c2d346c3fd8","type":"MultiLine"},{"attributes":{"plot":null,"text":""},"id":"e6ff08ba-7cfd-4e7c-b9eb-12e28efd7fb7","type":"Title"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"7ab74114-abdf-46af-82c3-62eb3c214279","type":"MultiLine"},{"attributes":{"data_source":{"id":"2ff7a181-6de4-42e1-8c48-1c821c33c33c","type":"ColumnDataSource"},"glyph":{"id":"bdbd2f9d-3cea-438f-a418-2fd1fd812ca0","type":"MultiLine"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5e4836a7-88f6-4107-8234-9751fee26393","type":"MultiLine"},"selection_glyph":null},"id":"b064c5a4-1b2d-40d4-92e4-48fba7b8a73e","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"ca409a87-5991-4810-94be-ea09ff591c30","type":"ColumnDataSource"},"glyph":{"id":"998aef9a-14b7-444f-bd6f-2c2d346c3fd8","type":"MultiLine"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7ab74114-abdf-46af-82c3-62eb3c214279","type":"MultiLine"},"selection_glyph":null},"id":"676f035d-4f7a-4bfe-911f-6556cc7f06a6","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"a157fd5c-4705-4b76-a71d-0a62a59263f3","type":"BoxAnnotation"},"plot":{"id":"e4df0572-2dc6-43da-be02-8913d91f5c08","subtype":"Figure","type":"Plot"}},"id":"f63cb962-99c6-4bc0-9c92-d682b1fb3824","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"e2f2397d-35fd-45ce-bdb3-f027a4b8de49","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"field":"line_color"},"line_width":{"value":6},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"bdbd2f9d-3cea-438f-a418-2fd1fd812ca0","type":"MultiLine"},{"attributes":{"callback":null,"column_names":["xs","ys"],"data":{"xs":[[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[0,0.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[1,1.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[2,2.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[3,3.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[4,4.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[5,5.8],[6,6.8],[6,6.8],[6,6.8],[6,6.8],[6,6.8],[6,6.8],[6,6.8],[6,6.8],[6,6.8],[6,6.8] ...
